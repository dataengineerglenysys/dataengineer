# %%
import requests
URL = "https://www.glenysys.com/"
response = requests.get(URL)
print(response.status_code)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
response_data = response.content
print(response_data)
# Out:
# 200
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n\n<head>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:300,400,700&display=swap" rel="stylesheet">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.7.0/animate.min.css">\n    <link rel="stylesheet" href="css/style.css">\n    <link rel="icon" href="img/fav-icon.png" sizes="16x16" type="image/png">\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.8.1/css/all.css"\n        integrity="sha384-50oBUHEmvpQ+1lW4y57PTFmhCaXp0ML5d60M1M7uH2+nqUivzIebhndOJK28anvf" crossorigin="anonymous">\n    <script type="text/javascript" src="js/wow.js"></script>\n    <link rel="stylesheet" type="text/css" href="slick/slick.css" />\n    <link rel="stylesheet" type="text/css" href="slick/slick-theme.css" />\n    <link rel="stylesheet" href="font-6/flaticon.css">\n    <link rel="stylesheet" href="font/flaticon.css">\n    <title>Glenysys</title>\n    <!---------------- library------------------->\n    <script src="js/jquery.js"></script>\n    <!---------------- library------------------->\n</head>\n\n<body>\n    <div class="full-wrapper">\n        <header>\n            <div class="header-main">\n\n                <div class="header-right">\n                    <div class="header-top">\n                        <ul>\n                            <li>\n                                <p><i class="fas fa-map-marker-alt"></i>&nbsp&nbsp75 Executive Center, Suite 413, Aurora, IL 60504</</p>\n                            </li>\n                            <li><a class="phone" href="">+1 (901)-878-9996</a></li>\n                            <li><a class="email" href="">info@glenysys.com </a></li>\n                            <li><a href=""><i class="fab fa-google-plus-g"></i></a></li>\n                            <li><a href=""><i class="fab fa-facebook-f"></i></a></li>\n                            <li><a href=""><i class="fab fa-instagram"></i></a></li>\n                            <li><a href=""><i class="fab fa-twitter"></i></a></li>\n                            <li><a href="https://www.linkedin.com/company/36137179"><i class="fab fa-linkedin-in"></i></a></li>\n                            <li><a class="qwef demo" href="JavaScript:Void(0);"><i class="fas fa-user"></i> Login</a>\n                            </li>\n                        </ul>\n                    </div>\n                    <div class="header-up">\n                        <div class="logo">\n                            <a href="index.html"><img src="img/logo.png" alt=""></a>\n                        </div>\n                        <div class="header-bottom">\n                            <ul>\n                                <li><a class="active" href="index.html">Home</a></li>\n                                <li><a href="aboutus.html">About Us</a></li>\n                                <li class="has-child">\n                                    <a href="services.html">Services</a>\n                                    <div class="dropdown">\n                                        <ul>\n                                            <li><a href="it-services.html">IT Services</a></li>\n                                            <li><a href="application-dev.html">Application Development</a></li>\n                                            <li><a href="big-data-dev.html">Big Data Development</a></li>\n                                            <li><a href="staffing-services.html">Staffing Services</a></li>\n                                            <li><a href="salesforce.html">Salesforce Development</a></li>\n                                            <li><a href="talent.html">Talend Development</a></li>\n                                        </ul>\n                                    </div>\n                                </li>\n                             ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response_data, 'html.parser')
#print(dir(soup))
urls = []
for i in soup.find_all('a'):
    print(i.get('href'))
# Out:
# https://www.linkedin.com/company/36137179
# JavaScript:Void(0);
# index.html
# index.html
# aboutus.html
# services.html
# it-services.html
# application-dev.html
# big-data-dev.html
# staffing-services.html
# salesforce.html
# talent.html
# career.html
# contact.html
# services.html
# services.html
# None
# None
# aboutus.html
# it-services.html
# application-dev.html
# big-data-dev.html
# staffing-services.html
# salesforce.html
# talent.html
#
#
#
#
#
#
#
#
# index.html
# aboutus.html
# services.html
# it-services.html
# application-dev.html
# big-data-dev.html
# staffing-services.html
# salesforce.html
# talent.html
# #
# career.html
# contact.html
# JavaScript:Void(0);
